# %%
from __future__ import print_function

import collections
import io
import math

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from IPython import display
from sklearn import metrics

# %% [markdown]
# ## Mục tiêu
#
# - Dự đoán chỉ số hạnh phúc của các quốc gia

# %% [markdown]
# ## Data

# %%
report = pd.read_csv('../data/world-happiness-report.csv')
report_21 = pd.read_csv('../data/world-happiness-report-2021.csv')

# %% [markdown]
# ## EDA

# %%
report.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
report.groupby(['Country name']).agg({'year': 'nunique'})
# Out:
#               year
# Country name
# Afghanistan     12
# Albania         13
# Algeria          8
# Angola           4
# Argentina       15
# ...            ...
# Venezuela       15
# Vietnam         14
# Yemen           12
# Zambia          14
# Zimbabwe        15
#
# [166 rows x 1 columns]
